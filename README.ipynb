# %%
import numpy, scipy, sklearn, librosa

# %%
x, fs = librosa.load('example.wav')

# %%
x
# Out:
# array([ 0.        ,  0.        ,  0.        , ..., -0.00014405,
#        -0.00047313, -0.00066273], dtype=float32)

# %%
fs
# Out:
# 22050

# %%
import librosa.display

# %%
librosa.display.waveplot(x, sr=fs)

# %%
mfccs = librosa.feature.mfcc(x, sr=fs)

# %%
print(mfccs.shape)
# Out:
# (20, 1089)

# %%
librosa.display.specshow(mfccs, sr=fs, x_axis='time')

# %%
mfccs = sklearn.preprocessing.scale(mfccs, axis=1)

# %%
librosa.display.specshow(mfccs, sr=fs, x_axis='time')

# %%
mfccs
# Out:
# array([[-5.10879232, -5.10879232, -5.10879232, ..., -1.583473  ,
#         -1.47036897, -1.59570439],
#        [-2.4849709 , -2.4849709 , -2.4849709 , ..., -0.86908345,
#         -1.02172157, -1.02766908],
#        [ 1.01757543,  1.01757543,  1.01757543, ...,  0.23347172,
#         -0.15679983, -0.00799075],
#        ...,
#        [ 0.03514553,  0.03514553,  0.03514553, ..., -0.36003844,
#         -0.18134829,  0.05898519],
#        [ 0.06621857,  0.06621857,  0.06621857, ...,  0.90337075,
#          0.72961387,  0.67400324],
#        [-0.15067929, -0.15067929, -0.15067929, ...,  0.32444116,
#         -0.73992338, -0.85672208]])
